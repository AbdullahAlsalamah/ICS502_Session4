# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from collections import deque
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, LSTM
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')

# %%
daysToPredict = 14
country = 'US'
feature = "confirmed" # 'confirmed' or 'deaths'
numFeatures = 1
learningRate = 0.001
inputSize = 7

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_' + feature + '_global.csv')
print(df.shape)
# Out:
# (271, 321)

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  11/26/20  \
# 0        0        0        0        0  ...     45174     45384     45600
# 1        0        0        0        0  ...     34300     34944     35600
# 2        0        0        0        0  ...     77000     78025     79110
# 3        0        0        0        0  ...      6351      6428      6534
# 4        0        0        0        0  ...     14742     14821     14920
#
#    11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  12/3/20
# 0     45723     45844     46116     46274    46717    46980    46718
# 1     36245     36790     37625     38182    39014    39719    40501
# 2     80168     81212     82221     83199    84152    85084    85927
# 3      6610      6610      6712      6745     6790     6842     6904
# 4     15008     15087     15103     15139    15251    15319    15361
#
# [5 rows x 321 columns]

# %%
df = df[df['Country/Region'] == country]
df.head()
# Out:
#     Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 218            NaN   Saudi Arabia  23.885942  45.079162        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  11/26/20  \
# 218        0        0        0        0  ...    355741    356067    356389
#
#      11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  12/3/20
# 218    356691    356911    357128    357360   357623   357872   358102
#
# [1 rows x 321 columns]

# %%
df[df.columns[4:]].sum(axis=1)
# Out:
# 218    54734287
# dtype: int64

# %%
df_death = pd.DataFrame(df[df.columns[4:]].sum(), columns=[feature])
df_death.index = pd.to_datetime(df_death.index)
df_death.tail()
# Out:
#             confirmed
# 2020-11-29     357128
# 2020-11-30     357360
# 2020-12-01     357623
# 2020-12-02     357872
# 2020-12-03     358102

# %%
df_death.plot(figsize=(10,5), title=country);

# %%
train = df_death.iloc[:-daysToPredict]
test = df_death.iloc[-daysToPredict:]
print(len(train))
print(len(test))
# Out:
# 303
# 14

# %%
scaler = MinMaxScaler()
scaler.fit(train);

# %%
scaledTrain = scaler.transform(train)
scaledTest = scaler.transform(test)

# %%
generator = TimeseriesGenerator(scaledTrain, scaledTrain, length=inputSize, batch_size=1)

# %%
print(len(scaledTrain))
print(len(generator))
# Out:
# 303
# 296

# %%
model = Sequential()
model.add(LSTM(150, activation='relu', input_shape=(inputSize, numFeatures), return_sequences=True))

model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(32, activation='relu'))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.5))
model.add(Dense(1))

# opt = Adam(lr=learningRate, decay=1e-6)
model.compile(optimizer="adam", loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_48 (LSTM)               (None, 7, 150)            91200
# _________________________________________________________________
# lstm_49 (LSTM)               (None, 7, 64)             55040
# _________________________________________________________________
# lstm_50 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_62 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 159,745
# Trainable params: 159,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
val_set = np.append(scaledTrain[55], scaledTest)
val_set = val_set.reshape(daysToPredict+1,1)

# %%
val_gen = TimeseriesGenerator(val_set, val_set, length=inputSize, batch_size=numFeatures)

# %%
earlyStopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %%
# model.fit_generator(generator, validation_data=val_gen, epochs=100, callbacks=[earlyStopping], steps_per_epoch=10);
model.fit_generator(generator, validation_data=val_gen, epochs=100, steps_per_epoch=10);
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3948 - val_loss: 0.8403
# Epoch 2/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1464 - val_loss: 0.6424
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1925 - val_loss: 0.1857
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0358 - val_loss: 0.0696
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0709 - val_loss: 0.0506
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0164 - val_loss: 0.0148
# Epoch 7/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0216 - val_loss: 0.0172
# Epoch 8/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0241
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0250
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.1775
# Epoch 11/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0936 - val_loss: 0.2148
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0522 - val_loss: 0.1345
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0135 - val_loss: 0.0128
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0302 - val_loss: 0.0160
# Epoch 15/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0211 - val_loss: 0.1072
# Epoch 16/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0446 - val_loss: 0.0407
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0381 - val_loss: 0.0339
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0227 - val_loss: 0.1163
# Epoch 19/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0224 - val_loss: 0.0786
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 0.0180
# Epoch 21/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0308
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0107 - val_loss: 0.0212
# Epoch 23/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0262 - val_loss: 0.0122
# Epoch 24/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0107 - val_loss: 0.0127
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0147 - val_loss: 0.0261
# Epoch 26/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0710
# Epoch 27/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0287 - val_loss: 0.0289
# Epoch 28/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0125
# Epoch 29/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0283 - val_loss: 0.0328
# Epoch 30/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0172
# Epoch 31/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0197 - val_loss: 0.0182
# Epoch 32/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0198
# Epoch 33/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0266 - val_loss: 0.0257
# Epoch 34/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0143
# Epoch 35/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0169 - val_loss: 0.0590
# Epoch 36/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0167 - val_loss: 0.0361
# Epoch 37/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0152 - val_loss: 0.0397
# Epoch 38/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0171 - val_loss: 0.0297
# Epoch 39/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0174 - val_loss: 0.0131
# Epoch 40/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0040 - val_loss: 0.1036
# Epoch 41/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0244 - val_loss: 0.0227
# Epoch 42/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0095
# Epoch 43/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0162
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0329 - val_loss: 0.0209
# Epoch 45/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0082
# Epoch 46/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0134
# Epoch 47/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0319 - val_loss: 0.0471
# Epoch 48/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0091
# Epoch 49/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0195
# Epoch 50/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0030 - val_loss: 0.0720
# Epoch 51/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0256 - val_loss: 0.0121
# Epoch 52/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0197 - val_loss: 0.0204
# Epoch 53/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0107
# Epoch 54/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0161 - val_loss: 0.0743
# Epoch 55/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0138 - val_loss: 0.0291
# Epoch 56/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0108
# Epoch 57/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0165 - val_loss: 0.0147
# Epoch 58/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0309 - val_loss: 0.0212
# Epoch 59/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0055 - val_loss: 0.0214
# Epoch 60/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 61/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0100
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0178
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0215 - val_loss: 0.0083
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0115 - val_loss: 0.0230
# Epoch 65/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0088
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0285 - val_loss: 0.0318
# Epoch 67/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0225 - val_loss: 0.0193
# Epoch 68/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0156 - val_loss: 0.0075
# Epoch 69/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0161 - val_loss: 0.0204
# Epoch 70/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0113
# Epoch 71/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0172 - val_loss: 0.0100
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0138
# Epoch 73/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0121 - val_loss: 0.0169
# Epoch 74/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0178
# Epoch 75/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0142 - val_loss: 0.0088
# Epoch 76/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0287 - val_loss: 0.0081
# Epoch 77/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0312 - val_loss: 0.0674
# Epoch 78/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0232 - val_loss: 0.0088
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0151 - val_loss: 0.0153
# Epoch 80/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0310
# Epoch 81/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0259
# Epoch 82/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0333
# Epoch 83/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0243
# Epoch 84/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0135
# Epoch 85/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0131
# Epoch 86/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0281 - val_loss: 0.0105
# Epoch 87/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0254 - val_loss: 0.0109
# Epoch 88/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0337
# Epoch 89/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0072
# Epoch 90/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0148 - val_loss: 0.0098
# Epoch 91/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0031 - val_loss: 0.0084
# Epoch 92/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0190
# Epoch 93/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0188 - val_loss: 0.0082
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0168 - val_loss: 0.0184
# Epoch 95/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0333 - val_loss: 0.0762
# Epoch 96/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0669
# Epoch 97/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0316 - val_loss: 0.0066
# Epoch 98/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0084
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0148 - val_loss: 0.0182
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0139 - val_loss: 0.0092

# %%
pd.DataFrame(model.history.history).plot(title="loss vs epochs curve");

# %%
testPred = []

firstEval = scaledTrain[-inputSize:]
currentBatch = firstEval.reshape(1, inputSize, numFeatures)

# %%
for i in range(len(test)+daysToPredict):
    currentPred = model.predict(currentBatch)[0]
    testPred.append(currentPred)
    currentBatch = np.append(currentBatch[:,1:,:], [[currentPred]], axis=1)

# %%
testPred
# Out:
# [array([0.97947377], dtype=float32),
#  array([0.97967106], dtype=float32),
#  array([0.9792566], dtype=float32),
#  array([0.97832394], dtype=float32),
#  array([0.9766705], dtype=float32),
#  array([0.97423023], dtype=float32),
#  array([0.9709941], dtype=float32),
#  array([0.96699935], dtype=float32),
#  array([0.96627766], dtype=float32),
#  array([0.96517444], dtype=float32),
#  array([0.9637903], dtype=float32),
#  array([0.9621861], dtype=float32),
#  array([0.96050644], dtype=float32),
#  array([0.95891994], dtype=float32),
#  array([0.95761335], dtype=float32),
#  array([0.9567641], dtype=float32),
#  array([0.9558], dtype=float32),
#  array([0.9547929], dtype=float32),
#  array([0.95380116], dtype=float32),
#  array([0.9528818], dtype=float32),
#  array([0.9520679], dtype=float32),
#  array([0.95136076], dtype=float32),
#  array([0.9507238], dtype=float32),
#  array([0.95008355], dtype=float32),
#  array([0.9494687], dtype=float32),
#  array([0.9488965], dtype=float32),
#  array([0.9483757], dtype=float32),
#  array([0.9479029], dtype=float32)]

# %%
truePred = scaler.inverse_transform(testPred)
truePred[:,0]
# Out:
# array([347249.89713794, 347319.84225696, 347172.89411265, 346842.25022221,
#        346256.06363559, 345390.92069966, 344243.63056457, 342827.37925881,
#        342571.5195908 , 342180.39747357, 341689.6828047 , 341120.95080066,
#        340525.46637344, 339963.0104118 , 339499.78776705, 339198.70678341,
#        338856.90548426, 338499.8684054 , 338148.26211071, 337822.33053493,
#        337533.78050464, 337283.07691187, 337057.26617414, 336830.27207488,
#        336612.27997583, 336409.43913066, 336224.79246902, 336057.17776084])

# %%
timeSeriesArr = test.index
for k in range(0,daysToPredict):
    timeSeriesArr = timeSeriesArr.append(timeSeriesArr[-1:] + pd.DateOffset(1))

df_forecast = pd.DataFrame(columns=[feature, "prediction"], index=timeSeriesArr)
df_forecast
# Out:
#            confirmed prediction
# 2020-11-20       NaN        NaN
# 2020-11-21       NaN        NaN
# 2020-11-22       NaN        NaN
# 2020-11-23       NaN        NaN
# 2020-11-24       NaN        NaN
# 2020-11-25       NaN        NaN
# 2020-11-26       NaN        NaN
# 2020-11-27       NaN        NaN
# 2020-11-28       NaN        NaN
# 2020-11-29       NaN        NaN
# 2020-11-30       NaN        NaN
# 2020-12-01       NaN        NaN
# 2020-12-02       NaN        NaN
# 2020-12-03       NaN        NaN
# 2020-12-04       NaN        NaN
# 2020-12-05       NaN        NaN
# 2020-12-06       NaN        NaN
# 2020-12-07       NaN        NaN
# 2020-12-08       NaN        NaN
# 2020-12-09       NaN        NaN
# 2020-12-10       NaN        NaN
# 2020-12-11       NaN        NaN
# 2020-12-12       NaN        NaN
# 2020-12-13       NaN        NaN
# 2020-12-14       NaN        NaN
# 2020-12-15       NaN        NaN
# 2020-12-16       NaN        NaN
# 2020-12-17       NaN        NaN

# %%
df_forecast.loc[:,"prediction"] = truePred[:,0]
df_forecast.loc[:,feature] = test[feature]

# %%
df_forecast
# Out:
#             confirmed     prediction
# 2020-11-20   354813.0  347249.897138
# 2020-11-21   355034.0  347319.842257
# 2020-11-22   355258.0  347172.894113
# 2020-11-23   355489.0  346842.250222
# 2020-11-24   355741.0  346256.063636
# 2020-11-25   356067.0  345390.920700
# 2020-11-26   356389.0  344243.630565
# 2020-11-27   356691.0  342827.379259
# 2020-11-28   356911.0  342571.519591
# 2020-11-29   357128.0  342180.397474
# 2020-11-30   357360.0  341689.682805
# 2020-12-01   357623.0  341120.950801
# 2020-12-02   357872.0  340525.466373
# 2020-12-03   358102.0  339963.010412
# 2020-12-04        NaN  339499.787767
# 2020-12-05        NaN  339198.706783
# 2020-12-06        NaN  338856.905484
# 2020-12-07        NaN  338499.868405
# 2020-12-08        NaN  338148.262111
# 2020-12-09        NaN  337822.330535
# 2020-12-10        NaN  337533.780505
# 2020-12-11        NaN  337283.076912
# 2020-12-12        NaN  337057.266174
# 2020-12-13        NaN  336830.272075
# 2020-12-14        NaN  336612.279976
# 2020-12-15        NaN  336409.439131
# 2020-12-16        NaN  336224.792469
# 2020-12-17        NaN  336057.177761

# %%
df_forecast.plot(title="Number of " + feature + " for the next 7 days in Saudi Arabia");
